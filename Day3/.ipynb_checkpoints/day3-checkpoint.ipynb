# %% [markdown]
# # Importing

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# # Opening the data file
df = pd.read_csv('https://raw.githubusercontent.com/ShamilaWije/DataStorm3/main/train_data.csv')
vd = pd.read_csv('https://raw.githubusercontent.com/ShamilaWije/DataStorm3/main/validation_data.csv')
td = pd.read_csv('https://raw.githubusercontent.com/ShamilaWije/DataStorm3/main/test_data.csv')
# df = pd.read_csv('train_data.csv')
# vd = pd.read_csv('validation_data.csv')
# td = pd.read_csv('test_data.csv')
df
# Out:
#       CategoryCode  ItemCode      DateID  DailySales
# 0       category_2    117610   11/6/2021           7
# 1       category_4    836584  11/18/2021          16
# 2       category_1    370195   1/24/2022           6
# 3       category_2    172582  10/30/2021           5
# 4       category_2   1006009  10/30/2021           5
# ...            ...       ...         ...         ...
# 19916   category_2    225259   10/4/2021           4
# 19917   category_2    111436  10/12/2021           1
# 19918   category_2   1098502   10/1/2021           1
# 19919   category_2     20824   10/1/2021           7
# 19920   category_1    371104   10/4/2021           4
#
# [19921 rows x 4 columns]

# %% [markdown]
# # First look

# %%
df.describe()
# Out:
#            ItemCode    DailySales
# count  1.992100e+04  19921.000000
# mean   6.110610e+05      7.351890
# std    4.549868e+05     14.605342
# min    3.418000e+03      1.000000
# 25%    1.176100e+05      2.000000
# 50%    8.379430e+05      3.000000
# 75%    1.058713e+06      7.000000
# max    1.105027e+06    434.000000

# %%
df['DateID'] = pd.to_datetime(df['DateID'])

# %%
df = df.sort_values('DateID')
df = df.reset_index(drop = True)
df
# Out:
#       CategoryCode  ItemCode     DateID  DailySales
# 0       category_2    174436 2021-10-01           9
# 1       category_2    118033 2021-10-01           4
# 2       category_2     20824 2021-10-01           7
# 3       category_1   1061341 2021-10-01          11
# 4       category_1     76399 2021-10-01          14
# ...            ...       ...        ...         ...
# 19916   category_2     57058 2022-02-13           3
# 19917   category_1   1084498 2022-02-13           4
# 19918   category_2   1067092 2022-02-13          13
# 19919   category_1    755584 2022-02-13           2
# 19920   category_3    893824 2022-02-13           1
#
# [19921 rows x 4 columns]

# %% [markdown]
# # Sorting data

# %%
df = df[(df['DateID'] >= '2021-10-04')]
df
# Out:
#       CategoryCode  ItemCode     DateID  DailySales
# 455     category_4   1024810 2021-10-04           6
# 456     category_2     59749 2021-10-04           3
# 457     category_1    370195 2021-10-04           1
# 458     category_2   1064473 2021-10-04           6
# 459     category_1   1081321 2021-10-04           3
# ...            ...       ...        ...         ...
# 19916   category_2     57058 2022-02-13           3
# 19917   category_1   1084498 2022-02-13           4
# 19918   category_2   1067092 2022-02-13          13
# 19919   category_1    755584 2022-02-13           2
# 19920   category_3    893824 2022-02-13           1
#
# [19466 rows x 4 columns]

# %%
df = df.reset_index(drop = True)
df
# Out:
#       CategoryCode  ItemCode     DateID  DailySales
# 0       category_4   1024810 2021-10-04           6
# 1       category_2     59749 2021-10-04           3
# 2       category_1    370195 2021-10-04           1
# 3       category_2   1064473 2021-10-04           6
# 4       category_1   1081321 2021-10-04           3
# ...            ...       ...        ...         ...
# 19461   category_2     57058 2022-02-13           3
# 19462   category_1   1084498 2022-02-13           4
# 19463   category_2   1067092 2022-02-13          13
# 19464   category_1    755584 2022-02-13           2
# 19465   category_3    893824 2022-02-13           1
#
# [19466 rows x 4 columns]

# %% [markdown]
# **check unique values in dataset**

# %%
# check unique values in dataset
df.apply(lambda x: len(x.unique()))
# Out:
# CategoryCode      4
# ItemCode        194
# DateID          133
# DailySales      159
# dtype: int64

# %% [markdown]
# **Check for null values**

# %%
# check for null values
df.isnull().sum()
# Out:
# CategoryCode    0
# ItemCode        0
# DateID          0
# DailySales      0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Category'] = le.fit_transform(df['CategoryCode'])
df
# Out:
#       CategoryCode  ItemCode     DateID  DailySales  Category
# 0       category_4   1024810 2021-10-04           6         3
# 1       category_2     59749 2021-10-04           3         1
# 2       category_1    370195 2021-10-04           1         0
# 3       category_2   1064473 2021-10-04           6         1
# 4       category_1   1081321 2021-10-04           3         0
# ...            ...       ...        ...         ...       ...
# 19461   category_2     57058 2022-02-13           3         1
# 19462   category_1   1084498 2022-02-13           4         0
# 19463   category_2   1067092 2022-02-13          13         1
# 19464   category_1    755584 2022-02-13           2         0
# 19465   category_3    893824 2022-02-13           1         2
#
# [19466 rows x 5 columns]

# %%
df['DateID'].dt.day
# Out:
# 0         4
# 1         4
# 2         4
# 3         4
# 4         4
#          ..
# 19461    13
# 19462    13
# 19463    13
# 19464    13
# 19465    13
# Name: DateID, Length: 19466, dtype: int64

# %%
def week_num(tgtdate):
    wDay = df.iloc[0,2]
    return(tgtdate-wDay).days//7 +1

# %%
df['Week'] = df['DateID'].apply(lambda x : week_num(x))

# %%
df
# Out:
#       CategoryCode  ItemCode     DateID  DailySales  Category  Week
# 0       category_4   1024810 2021-10-04           6         3     1
# 1       category_2     59749 2021-10-04           3         1     1
# 2       category_1    370195 2021-10-04           1         0     1
# 3       category_2   1064473 2021-10-04           6         1     1
# 4       category_1   1081321 2021-10-04           3         0     1
# ...            ...       ...        ...         ...       ...   ...
# 19461   category_2     57058 2022-02-13           3         1    19
# 19462   category_1   1084498 2022-02-13           4         0    19
# 19463   category_2   1067092 2022-02-13          13         1    19
# 19464   category_1    755584 2022-02-13           2         0    19
# 19465   category_3    893824 2022-02-13           1         2    19
#
# [19466 rows x 6 columns]

# %%
df = df.groupby(['Week', 'ItemCode', 'Category']).DailySales.agg([sum]).reset_index()
df
# Out:
#       Week  ItemCode  Category  sum
# 0        1      3418         0   42
# 1        1      3427         0   40
# 2        1      7666         2  119
# 3        1      9925         1    9
# 4        1     16936         2   25
# ...    ...       ...       ...  ...
# 3588    19   1101769         1   33
# 3589    19   1103056         1   10
# 3590    19   1105009         1   11
# 3591    19   1105018         1    6
# 3592    19   1105027         1   14
#
# [3593 rows x 4 columns]

# %%
df = df.rename(columns={'sum': 'Sales'})
df
# Out:
#       Week  ItemCode  Category  Sales
# 0        1      3418         0     42
# 1        1      3427         0     40
# 2        1      7666         2    119
# 3        1      9925         1      9
# 4        1     16936         2     25
# ...    ...       ...       ...    ...
# 3588    19   1101769         1     33
# 3589    19   1103056         1     10
# 3590    19   1105009         1     11
# 3591    19   1105018         1      6
# 3592    19   1105027         1     14
#
# [3593 rows x 4 columns]

# %%
df['Category'].value_counts()
# Out:
# 1    1665
# 0    1246
# 2     413
# 3     269
# Name: Category, dtype: int64

# %%
cor = df.corr()
sns.heatmap(cor, annot=True)

# %%
fvd = vd.pivot_table(index='Week', values='WeeklySales', columns ='ItemCode', fill_value=0 ,aggfunc=sum).reset_index()
fvd
# Out:
# ItemCode Week  3418  3427  7666  17287  17296  20824  23569  24136  30877  \
# 0          w1    25     7    48     57    366    137     20     20     65
# 1          w2    69    56    16     60    514    150     60     56     93
# 2          w3   120    72     0     83    728    148      2     37    107
# 3          w4    69    33    17     64    771    220     20     44    118
#
# ItemCode  ...  1090114  1090240  1090276  1090294  1090303  1097143  1098493  \
# 0         ...        3        3        3       11       19       43       10
# 1         ...       11        8        4       32       11       47        8
# 2         ...       11       13        6       12       14       32        9
# 3         ...       11        8       10       29       14       27        9
#
# ItemCode  1098502  1101661  1105009
# 0               7       64       11
# 1               6       69       10
# 2               7       54       10
# 3               4       88       19
#
# [4 rows x 96 columns]

# %%
fdf = df.pivot_table(index='Week', values='Sales', columns ='ItemCode',fill_value=0, aggfunc=sum).reset_index()
fdf
# Out:
# ItemCode  Week  3418  3427  7666  9925  16936  17287  17296  20824  23200  \
# 0            1    42    40   119     9     25     16    274    144      7
# 1            2    41    20   196    11     40      6    438    123     33
# 2            3    41    48   185    13     31     10    276    112      7
# 3            4    44    54    94     5     21     21    485    103     64
# 4            5    46    28    15    11     43     21    578    163     80
# 5            6    43    36    10    11      7     12    643    284     61
# 6            7    49    52    30    13     34     20    540    140     30
# 7            8    54    42    79    12    151     10    580    134    108
# 8            9    69    57    82    10     32     24    435    115    163
# 9           10   101    46   141    21     28     23    595    122    195
# 10          11    73    45   219    15     25      6    569    103    149
# 11          12    75    78   125    17     49     18    434    119     73
# 12          13    56    39   107    19     40     21    481    116     95
# 13          14    83    66    15     8     74     21    621     91      0
# 14          15    85    32    26     9     66     17    503    126      0
# 15          16    89    34    28    14     43     28    909     94      0
# 16          17    67    29    38    10     66     82    301    122      0
# 17          18   109    58    41     8     48     14    574    136      0
# 18          19    72    35    39    21     71     23    331    136     22
#
# ItemCode  ...  1098502  1101553  1101562  1101571  1101661  1101769  1103056  \
# 0         ...        8       11        9        7       22        3        0
# 1         ...        7       10        8       18       26        0        8
# 2         ...        4        5       10        7       14        0       12
# 3         ...        9        3       19        6       41       18       28
# 4         ...        3        5        4        7       23       20       27
# 5         ...        9        9       13        3       14       22       20
# 6         ...        3        5        9        8       45       17       17
# 7         ...        9        6       10        4       38       14       24
# 8         ...        9        3        0        3       27        1       19
# 9         ...        4       16        7        2       26        0       12
# 10        ...        5       17       27        2       57        2        7
# 11        ...        5        5       31       81       27        0       18
# 12        ...        6        6       12       88       31        0       14
# 13        ...        6       21        6        1       31        5       16
# 14        ...        2        8       14       57       53        7       16
# 15        ...       10        2       13       56       65       20       15
# 16        ...        9        1        2        8       39       32       13
# 17        ...       10        5        6        7       53       20       18
# 18        ...        5        1        7       17       27       33       10
#
# ItemCode  1105009  1105018  1105027
# 0               0        0        0
# 1               0        0        0
# 2               5        0        0
# 3               5        3        3
# 4              10        6       11
# 5              17       11       10
# 6              17        4        7
# 7               4        7       16
# 8               6        8       13
# 9               9        6       10
# 10              4        7       12
# 11              7       10        7
# 12              3       15       12
# 13              6        4       12
# 14              6       10        6
# 15              7       10        5
# 16              5       13        8
# 17              9        3        7
# 18             11        6       14
#
# [19 rows x 195 columns]

# %% [markdown]
# # Geting traing data ready to train

# %%
item = list(fdf.columns)
item.pop(0)
print(len(item))
# Out:
# 194

# %%
ffdf = pd.concat([fdf['Week'],fdf[item].cumsum()], axis=1)
ffdf
# Out:
#     Week  3418  3427  7666  9925  16936  17287  17296  20824  23200  ...  \
# 0      1    42    40   119     9     25     16    274    144      7  ...
# 1      2    83    60   315    20     65     22    712    267     40  ...
# 2      3   124   108   500    33     96     32    988    379     47  ...
# 3      4   168   162   594    38    117     53   1473    482    111  ...
# 4      5   214   190   609    49    160     74   2051    645    191  ...
# 5      6   257   226   619    60    167     86   2694    929    252  ...
# 6      7   306   278   649    73    201    106   3234   1069    282  ...
# 7      8   360   320   728    85    352    116   3814   1203    390  ...
# 8      9   429   377   810    95    384    140   4249   1318    553  ...
# 9     10   530   423   951   116    412    163   4844   1440    748  ...
# 10    11   603   468  1170   131    437    169   5413   1543    897  ...
# 11    12   678   546  1295   148    486    187   5847   1662    970  ...
# 12    13   734   585  1402   167    526    208   6328   1778   1065  ...
# 13    14   817   651  1417   175    600    229   6949   1869   1065  ...
# 14    15   902   683  1443   184    666    246   7452   1995   1065  ...
# 15    16   991   717  1471   198    709    274   8361   2089   1065  ...
# 16    17  1058   746  1509   208    775    356   8662   2211   1065  ...
# 17    18  1167   804  1550   216    823    370   9236   2347   1065  ...
# 18    19  1239   839  1589   237    894    393   9567   2483   1087  ...
#
#     1098502  1101553  1101562  1101571  1101661  1101769  1103056  1105009  \
# 0         8       11        9        7       22        3        0        0
# 1        15       21       17       25       48        3        8        0
# 2        19       26       27       32       62        3       20        5
# 3        28       29       46       38      103       21       48       10
# 4        31       34       50       45      126       41       75       20
# 5        40       43       63       48      140       63       95       37
# 6        43       48       72       56      185       80      112       54
# 7        52       54       82       60      223       94      136       58
# 8        61       57       82       63      250       95      155       64
# 9        65       73       89       65      276       95      167       73
# 10       70       90      116       67      333       97      174       77
# 11       75       95      147      148      360       97      192       84
# 12       81      101      159      236      391       97      206       87
# 13       87      122      165      237      422      102      222       93
# 14       89      130      179      294      475      109      238       99
# 15       99      132      192      350      540      129      253      106
# 16      108      133      194      358      579      161      266      111
# 17      118      138      200      365      632      181      284      120
# 18      123      139      207      382      659      214      294      131
#
#     1105018  1105027
# 0         0        0
# 1         0        0
# 2         0        0
# 3         3        3
# 4         9       14
# 5        20       24
# 6        24       31
# 7        31       47
# 8        39       60
# 9        45       70
# 10       52       82
# 11       62       89
# 12       77      101
# 13       81      113
# 14       91      119
# 15      101      124
# 16      114      132
# 17      117      139
# 18      123      153
#
# [19 rows x 195 columns]

# %%
ffdf[1044691]
# Out:
# 0      13
# 1      29
# 2      40
# 3      60
# 4      73
# 5      85
# 6     107
# 7     135
# 8     162
# 9     185
# 10    200
# 11    208
# 12    230
# 13    255
# 14    280
# 15    297
# 16    309
# 17    332
# 18    355
# Name: 1044691, dtype: int64

# %%
plt.scatter(ffdf['Week'],ffdf[item[1]])

# %%
ca = pd.concat([ ffdf['Week'],ffdf[item[1]] ], axis=1)
ca
# Out:
#     Week  3427
# 0      1    40
# 1      2    60
# 2      3   108
# 3      4   162
# 4      5   190
# 5      6   226
# 6      7   278
# 7      8   320
# 8      9   377
# 9     10   423
# 10    11   468
# 11    12   546
# 12    13   585
# 13    14   651
# 14    15   683
# 15    16   717
# 16    17   746
# 17    18   804
# 18    19   839

# %% [markdown]
# # **Pain**    (creating models)

# %% [markdown]
# Sklearn

# %%
from sklearn.linear_model import LinearRegression

# %%
nnn =0
for i in range(len(item)):
  print(f"L{item[i]} = LinearRegression(fit_intercept=True) \nL{item[i]}.fit(ca[['Week']],ffdf[[item[{nnn}]]])\n") 
  nnn = nnn + 1
# Out:
# L3418 = LinearRegression(fit_intercept=True)
# L3418.fit(ca[['Week']],ffdf[[item[0]]])
#
# L3427 = LinearRegression(fit_intercept=True)
# L3427.fit(ca[['Week']],ffdf[[item[1]]])
#
# L7666 = LinearRegression(fit_intercept=True)
# L7666.fit(ca[['Week']],ffdf[[item[2]]])
#
# L9925 = LinearRegression(fit_intercept=True)
# L9925.fit(ca[['Week']],ffdf[[item[3]]])
#
# L16936 = LinearRegression(fit_intercept=True)
# L16936.fit(ca[['Week']],ffdf[[item[4]]])
#
# L17287 = LinearRegression(fit_intercept=True)
# L17287.fit(ca[['Week']],ffdf[[item[5]]])
#
# L17296 = LinearRegression(fit_intercept=True)
# L17296.fit(ca[['Week']],ffdf[[item[6]]])
#
# L20824 = LinearRegression(fit_intercept=True)
# L20824.fit(ca[['Week']],ffdf[[item[7]]])
#
# L23200 = LinearRegression(fit_intercept=True)
# L23200.fit(ca[['Week']],ffdf[[item[8]]])
#
# L23569 = LinearRegression(fit_intercept=True)
# L23569.fit(ca[['Week']],ffdf[[item[9]]])
#
# L24136 = LinearRegression(fit_intercept=True)
# L24136.fit(ca[['Week']],ffdf[[item[10]]])
#
# L30877 = LinearRegression(fit_intercept=True)
# L30877.fit(ca[['Week']],ffdf[[item[11]]])
#
# L32245 = LinearRegression(fit_intercept=True)
# L32245.fit(ca[['Week']],ffdf[[item[12]]])
#
# L35449 = LinearRegression(fit_intercept=True)
# L35449.fit(ca[['Week']],ffdf[[item[13]]])
#
# L35530 = LinearRegression(fit_intercept=True)
# L35530.fit(ca[['Week']],ffdf[[item[14]]])
#
# L35584 = LinearRegression(fit_intercept=True)
# L35584.fit(ca[['Week']],ffdf[[item[15]]])
#
# L36898 = LinearRegression(fit_intercept=True)
# L36898.fit(ca[['Week']],ffdf[[item[16]]])
#
# L37510 = LinearRegression(fit_intercept=True)
# L37510.fit(ca[['Week']],ffdf[[item[17]]])
#
# L37861 = LinearRegression(fit_intercept=True)
# L37861.fit(ca[['Week']],ffdf[[item[18]]])
#
# L38518 = LinearRegression(fit_intercept=True)
# L38518.fit(ca[['Week']],ffdf[[item[19]]])
#
# L39436 = LinearRegression(fit_intercept=True)
# L39436.fit(ca[['Week']],ffdf[[item[20]]])
#
# L40759 = LinearRegression(fit_intercept=True)
# L40759.fit(ca[['Week']],ffdf[[item[21]]])
#
# L41830 = LinearRegression(fit_intercept=True)
# L41830.fit(ca[['Week']],ffdf[[item[22]]])
#
# L42424 = LinearRegression(fit_intercept=True)
# L42424.fit(ca[['Week']],ffdf[[item[23]]])
#
# L42496 = LinearRegression(fit_intercept=True)
# L42496.fit(ca[['Week']],ffdf[[item[24]]])
#
# L43630 = LinearRegression(fit_intercept=True)
# L43630.fit(ca[['Week']],ffdf[[item[25]]])
#
# L43657 = LinearRegression(fit_intercept=True)
# L43657.fit(ca[['Week']],ffdf[[item[26]]])
#
# L43738 = LinearRegression(fit_intercept=True)
# L43738.fit(ca[['Week']],ffdf[[item[27]]])
#
# L48940 = LinearRegression(fit_intercept=True)
# L48940.fit(ca[['Week']],ffdf[[item[28]]])
#
# L50785 = LinearRegression(fit_intercept=True)
# L50785.fit(ca[['Week']],ffdf[[item[29]]])
#
# L57058 = LinearRegression(fit_intercept=True)
# L57058.fit(ca[['Week']],ffdf[[item[30]]])
#
# L59047 = LinearRegression(fit_intercept=True)
# L59047.fit(ca[['Week']],ffdf[[item[31]]])
#
# L59749 = LinearRegression(fit_intercept=True)
# L59749.fit(ca[['Week']],ffdf[[item[32]]])
#
# L64978 = LinearRegression(fit_intercept=True)
# L64978.fit(ca[['Week']],ffdf[[item[33]]])
#
# L65788 = LinearRegression(fit_intercept=True)
# L65788.fit(ca[['Week']],ffdf[[item[34]]])
#
# L75886 = LinearRegression(fit_intercept=True)
# L75886.fit(ca[['Week']],ffdf[[item[35]]])
#
# L76399 = LinearRegression(fit_intercept=True)
# L76399.fit(ca[['Week']],ffdf[[item[36]]])
#
# L86974 = LinearRegression(fit_intercept=True)
# L86974.fit(ca[['Week']],ffdf[[item[37]]])
#
# L86992 = LinearRegression(fit_intercept=True)
# L86992.fit(ca[['Week']],ffdf[[item[38]]])
#
# L87046 = LinearRegression(fit_intercept=True)
# L87046.fit(ca[['Week']],ffdf[[item[39]]])
#
# L87559 = LinearRegression(fit_intercept=True)
# L87559.fit(ca[['Week']],ffdf[[item[40]]])
#
# L88450 = LinearRegression(fit_intercept=True)
# L88450.fit(ca[['Week']],ffdf[[item[41]]])
#
# L99079 = LinearRegression(fit_intercept=True)
# L99079.fit(ca[['Week']],ffdf[[item[42]]])
#
# L110320 = LinearRegression(fit_intercept=True)
# L110320.fit(ca[['Week']],ffdf[[item[43]]])
#
# L111382 = LinearRegression(fit_intercept=True)
# L111382.fit(ca[['Week']],ffdf[[item[44]]])
#
# L111436 = LinearRegression(fit_intercept=True)
# L111436.fit(ca[['Week']],ffdf[[item[45]]])
#
# L117610 = LinearRegression(fit_intercept=True)
# L117610.fit(ca[['Week']],ffdf[[item[46]]])
#
# L118033 = LinearRegression(fit_intercept=True)
# L118033.fit(ca[['Week']],ffdf[[item[47]]])
#
# L119554 = LinearRegression(fit_intercept=True)
# L119554.fit(ca[['Week']],ffdf[[item[48]]])
#
# L123307 = LinearRegression(fit_intercept=True)
# L123307.fit(ca[['Week']],ffdf[[item[49]]])
#
# L124774 = LinearRegression(fit_intercept=True)
# L124774.fit(ca[['Week']],ffdf[[item[50]]])
#
# L124954 = LinearRegression(fit_intercept=True)
# L124954.fit(ca[['Week']],ffdf[[item[51]]])
#
# L130993 = LinearRegression(fit_intercept=True)
# L130993.fit(ca[['Week']],ffdf[[item[52]]])
#
# L131983 = LinearRegression(fit_intercept=True)
# L131983.fit(ca[['Week']],ffdf[[item[53]]])
#
# L132028 = LinearRegression(fit_intercept=True)
# L132028.fit(ca[['Week']],ffdf[[item[54]]])
#
# L132334 = LinearRegression(fit_intercept=True)
# L132334.fit(ca[['Week']],ffdf[[item[55]]])
#
# L138742 = LinearRegression(fit_intercept=True)
# L138742.fit(ca[['Week']],ffdf[[item[56]]])
#
# L142756 = LinearRegression(fit_intercept=True)
# L142756.fit(ca[['Week']],ffdf[[item[57]]])
#
# L145330 = LinearRegression(fit_intercept=True)
# L145330.fit(ca[['Week']],ffdf[[item[58]]])
#
# L145978 = LinearRegression(fit_intercept=True)
# L145978.fit(ca[['Week']],ffdf[[item[59]]])
#
# L169504 = LinearRegression(fit_intercept=True)
# L169504.fit(ca[['Week']],ffdf[[item[60]]])
#
# L172033 = LinearRegression(fit_intercept=True)
# L172033.fit(ca[['Week']],ffdf[[item[61]]])
#
# L172582 = LinearRegression(fit_intercept=True)
# L172582.fit(ca[['Week']],ffdf[[item[62]]])
#
# L173617 = LinearRegression(fit_intercept=True)
# L173617.fit(ca[['Week']],ffdf[[item[63]]])
#
# L174436 = LinearRegression(fit_intercept=True)
# L174436.fit(ca[['Week']],ffdf[[item[64]]])
#
# L210868 = LinearRegression(fit_intercept=True)
# L210868.fit(ca[['Week']],ffdf[[item[65]]])
#
# L211309 = LinearRegression(fit_intercept=True)
# L211309.fit(ca[['Week']],ffdf[[item[66]]])
#
# L213802 = LinearRegression(fit_intercept=True)
# L213802.fit(ca[['Week']],ffdf[[item[67]]])
#
# L216151 = LinearRegression(fit_intercept=True)
# L216151.fit(ca[['Week']],ffdf[[item[68]]])
#
# L225259 = LinearRegression(fit_intercept=True)
# L225259.fit(ca[['Week']],ffdf[[item[69]]])
#
# L245581 = LinearRegression(fit_intercept=True)
# L245581.fit(ca[['Week']],ffdf[[item[70]]])
#
# L248272 = LinearRegression(fit_intercept=True)
# L248272.fit(ca[['Week']],ffdf[[item[71]]])
#
# L262384 = LinearRegression(fit_intercept=True)
# L262384.fit(ca[['Week']],ffdf[[item[72]]])
#
# L267478 = LinearRegression(fit_intercept=True)
# L267478.fit(ca[['Week']],ffdf[[item[73]]])
#
# L267496 = LinearRegression(fit_intercept=True)
# L267496.fit(ca[['Week']],ffdf[[item[74]]])
#
# L370195 = LinearRegression(fit_intercept=True)
# L370195.fit(ca[['Week']],ffdf[[item[75]]])
#
# L371104 = LinearRegression(fit_intercept=True)
# L371104.fit(ca[['Week']],ffdf[[item[76]]])
#
# L371239 = LinearRegression(fit_intercept=True)
# L371239.fit(ca[['Week']],ffdf[[item[77]]])
#
# L379249 = LinearRegression(fit_intercept=True)
# L379249.fit(ca[['Week']],ffdf[[item[78]]])
#
# L397213 = LinearRegression(fit_intercept=True)
# L397213.fit(ca[['Week']],ffdf[[item[79]]])
#
# L399220 = LinearRegression(fit_intercept=True)
# L399220.fit(ca[['Week']],ffdf[[item[80]]])
#
# L416212 = LinearRegression(fit_intercept=True)
# L416212.fit(ca[['Week']],ffdf[[item[81]]])
#
# L687616 = LinearRegression(fit_intercept=True)
# L687616.fit(ca[['Week']],ffdf[[item[82]]])
#
# L731104 = LinearRegression(fit_intercept=True)
# L731104.fit(ca[['Week']],ffdf[[item[83]]])
#
# L745945 = LinearRegression(fit_intercept=True)
# L745945.fit(ca[['Week']],ffdf[[item[84]]])
#
# L753613 = LinearRegression(fit_intercept=True)
# L753613.fit(ca[['Week']],ffdf[[item[85]]])
#
# L755584 = LinearRegression(fit_intercept=True)
# L755584.fit(ca[['Week']],ffdf[[item[86]]])
#
# L815101 = LinearRegression(fit_intercept=True)
# L815101.fit(ca[['Week']],ffdf[[item[87]]])
#
# L836125 = LinearRegression(fit_intercept=True)
# L836125.fit(ca[['Week']],ffdf[[item[88]]])
#
# L836152 = LinearRegression(fit_intercept=True)
# L836152.fit(ca[['Week']],ffdf[[item[89]]])
#
# L836584 = LinearRegression(fit_intercept=True)
# L836584.fit(ca[['Week']],ffdf[[item[90]]])
#
# L837943 = LinearRegression(fit_intercept=True)
# L837943.fit(ca[['Week']],ffdf[[item[91]]])
#
# L838456 = LinearRegression(fit_intercept=True)
# L838456.fit(ca[['Week']],ffdf[[item[92]]])
#
# L839356 = LinearRegression(fit_intercept=True)
# L839356.fit(ca[['Week']],ffdf[[item[93]]])
#
# L839374 = LinearRegression(fit_intercept=True)
# L839374.fit(ca[['Week']],ffdf[[item[94]]])
#
# L858886 = LinearRegression(fit_intercept=True)
# L858886.fit(ca[['Week']],ffdf[[item[95]]])
#
# L865933 = LinearRegression(fit_intercept=True)
# L865933.fit(ca[['Week']],ffdf[[item[96]]])
#
# L872260 = LinearRegression(fit_intercept=True)
# L872260.fit(ca[['Week']],ffdf[[item[97]]])
#
# L877624 = LinearRegression(fit_intercept=True)
# L877624.fit(ca[['Week']],ffdf[[item[98]]])
#
# L893824 = LinearRegression(fit_intercept=True)
# L893824.fit(ca[['Week']],ffdf[[item[99]]])
#
# L903976 = LinearRegression(fit_intercept=True)
# L903976.fit(ca[['Week']],ffdf[[item[100]]])
#
# L906586 = LinearRegression(fit_intercept=True)
# L906586.fit(ca[['Week']],ffdf[[item[101]]])
#
# L906595 = LinearRegression(fit_intercept=True)
# L906595.fit(ca[['Week']],ffdf[[item[102]]])
#
# L913561 = LinearRegression(fit_intercept=True)
# L913561.fit(ca[['Week']],ffdf[[item[103]]])
#
# L999403 = LinearRegression(fit_intercept=True)
# L999403.fit(ca[['Week']],ffdf[[item[104]]])
#
# L1003147 = LinearRegression(fit_intercept=True)
# L1003147.fit(ca[['Week']],ffdf[[item[105]]])
#
# L1003156 = LinearRegression(fit_intercept=True)
# L1003156.fit(ca[['Week']],ffdf[[item[106]]])
#
# L1003183 = LinearRegression(fit_intercept=True)
# L1003183.fit(ca[['Week']],ffdf[[item[107]]])
#
# L1003192 = LinearRegression(fit_intercept=True)
# L1003192.fit(ca[['Week']],ffdf[[item[108]]])
#
# L1006009 = LinearRegression(fit_intercept=True)
# L1006009.fit(ca[['Week']],ffdf[[item[109]]])
#
# L1006090 = LinearRegression(fit_intercept=True)
# L1006090.fit(ca[['Week']],ffdf[[item[110]]])
#
# L1006099 = LinearRegression(fit_intercept=True)
# L1006099.fit(ca[['Week']],ffdf[[item[111]]])
#
# L1006108 = LinearRegression(fit_intercept=True)
# L1006108.fit(ca[['Week']],ffdf[[item[112]]])
#
# L1010068 = LinearRegression(fit_intercept=True)
# L1010068.fit(ca[['Week']],ffdf[[item[113]]])
#
# L1013335 = LinearRegression(fit_intercept=True)
# L1013335.fit(ca[['Week']],ffdf[[item[114]]])
#
# L1015621 = LinearRegression(fit_intercept=True)
# L1015621.fit(ca[['Week']],ffdf[[item[115]]])
#
# L1021264 = LinearRegression(fit_intercept=True)
# L1021264.fit(ca[['Week']],ffdf[[item[116]]])
#
# L1024810 = LinearRegression(fit_intercept=True)
# L1024810.fit(ca[['Week']],ffdf[[item[117]]])
#
# L1026871 = LinearRegression(fit_intercept=True)
# L1026871.fit(ca[['Week']],ffdf[[item[118]]])
#
# L1030948 = LinearRegression(fit_intercept=True)
# L1030948.fit(ca[['Week']],ffdf[[item[119]]])
#
# L1032532 = LinearRegression(fit_intercept=True)
# L1032532.fit(ca[['Week']],ffdf[[item[120]]])
#
# L1032541 = LinearRegression(fit_intercept=True)
# L1032541.fit(ca[['Week']],ffdf[[item[121]]])
#
# L1032550 = LinearRegression(fit_intercept=True)
# L1032550.fit(ca[['Week']],ffdf[[item[122]]])
#
# L1032559 = LinearRegression(fit_intercept=True)
# L1032559.fit(ca[['Week']],ffdf[[item[123]]])
#
# L1032568 = LinearRegression(fit_intercept=True)
# L1032568.fit(ca[['Week']],ffdf[[item[124]]])
#
# L1032586 = LinearRegression(fit_intercept=True)
# L1032586.fit(ca[['Week']],ffdf[[item[125]]])
#
# L1044502 = LinearRegression(fit_intercept=True)
# L1044502.fit(ca[['Week']],ffdf[[item[126]]])
#
# L1044610 = LinearRegression(fit_intercept=True)
# L1044610.fit(ca[['Week']],ffdf[[item[127]]])
#
# L1044619 = LinearRegression(fit_intercept=True)
# L1044619.fit(ca[['Week']],ffdf[[item[128]]])
#
# L1044682 = LinearRegression(fit_intercept=True)
# L1044682.fit(ca[['Week']],ffdf[[item[129]]])
#
# L1044691 = LinearRegression(fit_intercept=True)
# L1044691.fit(ca[['Week']],ffdf[[item[130]]])
#
# L1047130 = LinearRegression(fit_intercept=True)
# L1047130.fit(ca[['Week']],ffdf[[item[131]]])
#
# L1047967 = LinearRegression(fit_intercept=True)
# L1047967.fit(ca[['Week']],ffdf[[item[132]]])
#
# L1048975 = LinearRegression(fit_intercept=True)
# L1048975.fit(ca[['Week']],ffdf[[item[133]]])
#
# L1049776 = LinearRegression(fit_intercept=True)
# L1049776.fit(ca[['Week']],ffdf[[item[134]]])
#
# L1050046 = LinearRegression(fit_intercept=True)
# L1050046.fit(ca[['Week']],ffdf[[item[135]]])
#
# L1054978 = LinearRegression(fit_intercept=True)
# L1054978.fit(ca[['Week']],ffdf[[item[136]]])
#
# L1056463 = LinearRegression(fit_intercept=True)
# L1056463.fit(ca[['Week']],ffdf[[item[137]]])
#
# L1058713 = LinearRegression(fit_intercept=True)
# L1058713.fit(ca[['Week']],ffdf[[item[138]]])
#
# L1060630 = LinearRegression(fit_intercept=True)
# L1060630.fit(ca[['Week']],ffdf[[item[139]]])
#
# L1060909 = LinearRegression(fit_intercept=True)
# L1060909.fit(ca[['Week']],ffdf[[item[140]]])
#
# L1061341 = LinearRegression(fit_intercept=True)
# L1061341.fit(ca[['Week']],ffdf[[item[141]]])
#
# L1061638 = LinearRegression(fit_intercept=True)
# L1061638.fit(ca[['Week']],ffdf[[item[142]]])
#
# L1063600 = LinearRegression(fit_intercept=True)
# L1063600.fit(ca[['Week']],ffdf[[item[143]]])
#
# L1064473 = LinearRegression(fit_intercept=True)
# L1064473.fit(ca[['Week']],ffdf[[item[144]]])
#
# L1064572 = LinearRegression(fit_intercept=True)
# L1064572.fit(ca[['Week']],ffdf[[item[145]]])
#
# L1066570 = LinearRegression(fit_intercept=True)
# L1066570.fit(ca[['Week']],ffdf[[item[146]]])
#
# L1067074 = LinearRegression(fit_intercept=True)
# L1067074.fit(ca[['Week']],ffdf[[item[147]]])
#
# L1067092 = LinearRegression(fit_intercept=True)
# L1067092.fit(ca[['Week']],ffdf[[item[148]]])
#
# L1067119 = LinearRegression(fit_intercept=True)
# L1067119.fit(ca[['Week']],ffdf[[item[149]]])
#
# L1067128 = LinearRegression(fit_intercept=True)
# L1067128.fit(ca[['Week']],ffdf[[item[150]]])
#
# L1068883 = LinearRegression(fit_intercept=True)
# L1068883.fit(ca[['Week']],ffdf[[item[151]]])
#
# L1070818 = LinearRegression(fit_intercept=True)
# L1070818.fit(ca[['Week']],ffdf[[item[152]]])
#
# L1070836 = LinearRegression(fit_intercept=True)
# L1070836.fit(ca[['Week']],ffdf[[item[153]]])
#
# L1071106 = LinearRegression(fit_intercept=True)
# L1071106.fit(ca[['Week']],ffdf[[item[154]]])
#
# L1071115 = LinearRegression(fit_intercept=True)
# L1071115.fit(ca[['Week']],ffdf[[item[155]]])
#
# L1071124 = LinearRegression(fit_intercept=True)
# L1071124.fit(ca[['Week']],ffdf[[item[156]]])
#
# L1074823 = LinearRegression(fit_intercept=True)
# L1074823.fit(ca[['Week']],ffdf[[item[157]]])
#
# L1075651 = LinearRegression(fit_intercept=True)
# L1075651.fit(ca[['Week']],ffdf[[item[158]]])
#
# L1076920 = LinearRegression(fit_intercept=True)
# L1076920.fit(ca[['Week']],ffdf[[item[159]]])
#
# L1076929 = LinearRegression(fit_intercept=True)
# L1076929.fit(ca[['Week']],ffdf[[item[160]]])
#
# L1076938 = LinearRegression(fit_intercept=True)
# L1076938.fit(ca[['Week']],ffdf[[item[161]]])
#
# L1077118 = LinearRegression(fit_intercept=True)
# L1077118.fit(ca[['Week']],ffdf[[item[162]]])
#
# L1081060 = LinearRegression(fit_intercept=True)
# L1081060.fit(ca[['Week']],ffdf[[item[163]]])
#
# L1081069 = LinearRegression(fit_intercept=True)
# L1081069.fit(ca[['Week']],ffdf[[item[164]]])
#
# L1081078 = LinearRegression(fit_intercept=True)
# L1081078.fit(ca[['Week']],ffdf[[item[165]]])
#
# L1081087 = LinearRegression(fit_intercept=True)
# L1081087.fit(ca[['Week']],ffdf[[item[166]]])
#
# L1081321 = LinearRegression(fit_intercept=True)
# L1081321.fit(ca[['Week']],ffdf[[item[167]]])
#
# L1081339 = LinearRegression(fit_intercept=True)
# L1081339.fit(ca[['Week']],ffdf[[item[168]]])
#
# L1082743 = LinearRegression(fit_intercept=True)
# L1082743.fit(ca[['Week']],ffdf[[item[169]]])
#
# L1084498 = LinearRegression(fit_intercept=True)
# L1084498.fit(ca[['Week']],ffdf[[item[170]]])
#
# L1085749 = LinearRegression(fit_intercept=True)
# L1085749.fit(ca[['Week']],ffdf[[item[171]]])
#
# L1090024 = LinearRegression(fit_intercept=True)
# L1090024.fit(ca[['Week']],ffdf[[item[172]]])
#
# L1090105 = LinearRegression(fit_intercept=True)
# L1090105.fit(ca[['Week']],ffdf[[item[173]]])
#
# L1090114 = LinearRegression(fit_intercept=True)
# L1090114.fit(ca[['Week']],ffdf[[item[174]]])
#
# L1090240 = LinearRegression(fit_intercept=True)
# L1090240.fit(ca[['Week']],ffdf[[item[175]]])
#
# L1090249 = LinearRegression(fit_intercept=True)
# L1090249.fit(ca[['Week']],ffdf[[item[176]]])
#
# L1090258 = LinearRegression(fit_intercept=True)
# L1090258.fit(ca[['Week']],ffdf[[item[177]]])
#
# L1090276 = LinearRegression(fit_intercept=True)
# L1090276.fit(ca[['Week']],ffdf[[item[178]]])
#
# L1090294 = LinearRegression(fit_intercept=True)
# L1090294.fit(ca[['Week']],ffdf[[item[179]]])
#
# L1090303 = LinearRegression(fit_intercept=True)
# L1090303.fit(ca[['Week']],ffdf[[item[180]]])
#
# L1092184 = LinearRegression(fit_intercept=True)
# L1092184.fit(ca[['Week']],ffdf[[item[181]]])
#
# L1097143 = LinearRegression(fit_intercept=True)
# L1097143.fit(ca[['Week']],ffdf[[item[182]]])
#
# L1098493 = LinearRegression(fit_intercept=True)
# L1098493.fit(ca[['Week']],ffdf[[item[183]]])
#
# L1098502 = LinearRegression(fit_intercept=True)
# L1098502.fit(ca[['Week']],ffdf[[item[184]]])
#
# L1101553 = LinearRegression(fit_intercept=True)
# L1101553.fit(ca[['Week']],ffdf[[item[185]]])
#
# L1101562 = LinearRegression(fit_intercept=True)
# L1101562.fit(ca[['Week']],ffdf[[item[186]]])
#
# L1101571 = LinearRegression(fit_intercept=True)
# L1101571.fit(ca[['Week']],ffdf[[item[187]]])
#
# L1101661 = LinearRegression(fit_intercept=True)
# L1101661.fit(ca[['Week']],ffdf[[item[188]]])
#
# L1101769 = LinearRegression(fit_intercept=True)
# L1101769.fit(ca[['Week']],ffdf[[item[189]]])
#
# L1103056 = LinearRegression(fit_intercept=True)
# L1103056.fit(ca[['Week']],ffdf[[item[190]]])
#
# L1105009 = LinearRegression(fit_intercept=True)
# L1105009.fit(ca[['Week']],ffdf[[item[191]]])
#
# L1105018 = LinearRegression(fit_intercept=True)
# L1105018.fit(ca[['Week']],ffdf[[item[192]]])
#
# L1105027 = LinearRegression(fit_intercept=True)
# L1105027.fit(ca[['Week']],ffdf[[item[193]]])

# %%
L3418 = LinearRegression(fit_intercept=True) 
L3418.fit(ca[['Week']],ffdf[[item[0]]])

L3427 = LinearRegression(fit_intercept=True) 
L3427.fit(ca[['Week']],ffdf[[item[1]]])

L7666 = LinearRegression(fit_intercept=True) 
L7666.fit(ca[['Week']],ffdf[[item[2]]])

L9925 = LinearRegression(fit_intercept=True) 
L9925.fit(ca[['Week']],ffdf[[item[3]]])

L16936 = LinearRegression(fit_intercept=True) 
L16936.fit(ca[['Week']],ffdf[[item[4]]])

L17287 = LinearRegression(fit_intercept=True) 
L17287.fit(ca[['Week']],ffdf[[item[5]]])

L17296 = LinearRegression(fit_intercept=True) 
L17296.fit(ca[['Week']],ffdf[[item[6]]])

L20824 = LinearRegression(fit_intercept=True) 
L20824.fit(ca[['Week']],ffdf[[item[7]]])

L23200 = LinearRegression(fit_intercept=True) 
L23200.fit(ca[['Week']],ffdf[[item[8]]])

L23569 = LinearRegression(fit_intercept=True) 
L23569.fit(ca[['Week']],ffdf[[item[9]]])

L24136 = LinearRegression(fit_intercept=True) 
L24136.fit(ca[['Week']],ffdf[[item[10]]])

L30877 = LinearRegression(fit_intercept=True) 
L30877.fit(ca[['Week']],ffdf[[item[11]]])

L32245 = LinearRegression(fit_intercept=True) 
L32245.fit(ca[['Week']],ffdf[[item[12]]])

L35449 = LinearRegression(fit_intercept=True) 
L35449.fit(ca[['Week']],ffdf[[item[13]]])

L35530 = LinearRegression(fit_intercept=True) 
L35530.fit(ca[['Week']],ffdf[[item[14]]])

L35584 = LinearRegression(fit_intercept=True) 
L35584.fit(ca[['Week']],ffdf[[item[15]]])

L36898 = LinearRegression(fit_intercept=True) 
L36898.fit(ca[['Week']],ffdf[[item[16]]])

L37510 = LinearRegression(fit_intercept=True) 
L37510.fit(ca[['Week']],ffdf[[item[17]]])

L37861 = LinearRegression(fit_intercept=True) 
L37861.fit(ca[['Week']],ffdf[[item[18]]])

L38518 = LinearRegression(fit_intercept=True) 
L38518.fit(ca[['Week']],ffdf[[item[19]]])

L39436 = LinearRegression(fit_intercept=True) 
L39436.fit(ca[['Week']],ffdf[[item[20]]])

L40759 = LinearRegression(fit_intercept=True) 
L40759.fit(ca[['Week']],ffdf[[item[21]]])

L41830 = LinearRegression(fit_intercept=True) 
L41830.fit(ca[['Week']],ffdf[[item[22]]])

L42424 = LinearRegression(fit_intercept=True) 
L42424.fit(ca[['Week']],ffdf[[item[23]]])

L42496 = LinearRegression(fit_intercept=True) 
L42496.fit(ca[['Week']],ffdf[[item[24]]])

L43630 = LinearRegression(fit_intercept=True) 
L43630.fit(ca[['Week']],ffdf[[item[25]]])

L43657 = LinearRegression(fit_intercept=True) 
L43657.fit(ca[['Week']],ffdf[[item[26]]])

L43738 = LinearRegression(fit_intercept=True) 
L43738.fit(ca[['Week']],ffdf[[item[27]]])

L48940 = LinearRegression(fit_intercept=True) 
L48940.fit(ca[['Week']],ffdf[[item[28]]])

L50785 = LinearRegression(fit_intercept=True) 
L50785.fit(ca[['Week']],ffdf[[item[29]]])

L57058 = LinearRegression(fit_intercept=True) 
L57058.fit(ca[['Week']],ffdf[[item[30]]])

L59047 = LinearRegression(fit_intercept=True) 
L59047.fit(ca[['Week']],ffdf[[item[31]]])

L59749 = LinearRegression(fit_intercept=True) 
L59749.fit(ca[['Week']],ffdf[[item[32]]])

L64978 = LinearRegression(fit_intercept=True) 
L64978.fit(ca[['Week']],ffdf[[item[33]]])

L65788 = LinearRegression(fit_intercept=True) 
L65788.fit(ca[['Week']],ffdf[[item[34]]])

L75886 = LinearRegression(fit_intercept=True) 
L75886.fit(ca[['Week']],ffdf[[item[35]]])

L76399 = LinearRegression(fit_intercept=True) 
L76399.fit(ca[['Week']],ffdf[[item[36]]])

L86974 = LinearRegression(fit_intercept=True) 
L86974.fit(ca[['Week']],ffdf[[item[37]]])

L86992 = LinearRegression(fit_intercept=True) 
L86992.fit(ca[['Week']],ffdf[[item[38]]])

L87046 = LinearRegression(fit_intercept=True) 
L87046.fit(ca[['Week']],ffdf[[item[39]]])

L87559 = LinearRegression(fit_intercept=True) 
L87559.fit(ca[['Week']],ffdf[[item[40]]])

L88450 = LinearRegression(fit_intercept=True) 
L88450.fit(ca[['Week']],ffdf[[item[41]]])

L99079 = LinearRegression(fit_intercept=True) 
L99079.fit(ca[['Week']],ffdf[[item[42]]])

L110320 = LinearRegression(fit_intercept=True) 
L110320.fit(ca[['Week']],ffdf[[item[43]]])

L111382 = LinearRegression(fit_intercept=True) 
L111382.fit(ca[['Week']],ffdf[[item[44]]])

L111436 = LinearRegression(fit_intercept=True) 
L111436.fit(ca[['Week']],ffdf[[item[45]]])

L117610 = LinearRegression(fit_intercept=True) 
L117610.fit(ca[['Week']],ffdf[[item[46]]])

L118033 = LinearRegression(fit_intercept=True) 
L118033.fit(ca[['Week']],ffdf[[item[47]]])

L119554 = LinearRegression(fit_intercept=True) 
L119554.fit(ca[['Week']],ffdf[[item[48]]])

L123307 = LinearRegression(fit_intercept=True) 
L123307.fit(ca[['Week']],ffdf[[item[49]]])

L124774 = LinearRegression(fit_intercept=True) 
L124774.fit(ca[['Week']],ffdf[[item[50]]])

L124954 = LinearRegression(fit_intercept=True) 
L124954.fit(ca[['Week']],ffdf[[item[51]]])

L130993 = LinearRegression(fit_intercept=True) 
L130993.fit(ca[['Week']],ffdf[[item[52]]])

L131983 = LinearRegression(fit_intercept=True) 
L131983.fit(ca[['Week']],ffdf[[item[53]]])

L132028 = LinearRegression(fit_intercept=True) 
L132028.fit(ca[['Week']],ffdf[[item[54]]])

L132334 = LinearRegression(fit_intercept=True) 
L132334.fit(ca[['Week']],ffdf[[item[55]]])

L138742 = LinearRegression(fit_intercept=True) 
L138742.fit(ca[['Week']],ffdf[[item[56]]])

L142756 = LinearRegression(fit_intercept=True) 
L142756.fit(ca[['Week']],ffdf[[item[57]]])

L145330 = LinearRegression(fit_intercept=True) 
L145330.fit(ca[['Week']],ffdf[[item[58]]])

L145978 = LinearRegression(fit_intercept=True) 
L145978.fit(ca[['Week']],ffdf[[item[59]]])

L169504 = LinearRegression(fit_intercept=True) 
L169504.fit(ca[['Week']],ffdf[[item[60]]])

L172033 = LinearRegression(fit_intercept=True) 
L172033.fit(ca[['Week']],ffdf[[item[61]]])

L172582 = LinearRegression(fit_intercept=True) 
L172582.fit(ca[['Week']],ffdf[[item[62]]])

L173617 = LinearRegression(fit_intercept=True) 
L173617.fit(ca[['Week']],ffdf[[item[63]]])

L174436 = LinearRegression(fit_intercept=True) 
L174436.fit(ca[['Week']],ffdf[[item[64]]])

L210868 = LinearRegression(fit_intercept=True) 
L210868.fit(ca[['Week']],ffdf[[item[65]]])

L211309 = LinearRegression(fit_intercept=True) 
L211309.fit(ca[['Week']],ffdf[[item[66]]])

L213802 = LinearRegression(fit_intercept=True) 
L213802.fit(ca[['Week']],ffdf[[item[67]]])

L216151 = LinearRegression(fit_intercept=True) 
L216151.fit(ca[['Week']],ffdf[[item[68]]])

L225259 = LinearRegression(fit_intercept=True) 
L225259.fit(ca[['Week']],ffdf[[item[69]]])

L245581 = LinearRegression(fit_intercept=True) 
L245581.fit(ca[['Week']],ffdf[[item[70]]])

L248272 = LinearRegression(fit_intercept=True) 
L248272.fit(ca[['Week']],ffdf[[item[71]]])

L262384 = LinearRegression(fit_intercept=True) 
L262384.fit(ca[['Week']],ffdf[[item[72]]])

L267478 = LinearRegression(fit_intercept=True) 
L267478.fit(ca[['Week']],ffdf[[item[73]]])

L267496 = LinearRegression(fit_intercept=True) 
L267496.fit(ca[['Week']],ffdf[[item[74]]])

L370195 = LinearRegression(fit_intercept=True) 
L370195.fit(ca[['Week']],ffdf[[item[75]]])

L371104 = LinearRegression(fit_intercept=True) 
L371104.fit(ca[['Week']],ffdf[[item[76]]])

L371239 = LinearRegression(fit_intercept=True) 
L371239.fit(ca[['Week']],ffdf[[item[77]]])

L379249 = LinearRegression(fit_intercept=True) 
L379249.fit(ca[['Week']],ffdf[[item[78]]])

L397213 = LinearRegression(fit_intercept=True) 
L397213.fit(ca[['Week']],ffdf[[item[79]]])

L399220 = LinearRegression(fit_intercept=True) 
L399220.fit(ca[['Week']],ffdf[[item[80]]])

L416212 = LinearRegression(fit_intercept=True) 
L416212.fit(ca[['Week']],ffdf[[item[81]]])

L687616 = LinearRegression(fit_intercept=True) 
L687616.fit(ca[['Week']],ffdf[[item[82]]])

L731104 = LinearRegression(fit_intercept=True) 
L731104.fit(ca[['Week']],ffdf[[item[83]]])

L745945 = LinearRegression(fit_intercept=True) 
L745945.fit(ca[['Week']],ffdf[[item[84]]])

L753613 = LinearRegression(fit_intercept=True) 
L753613.fit(ca[['Week']],ffdf[[item[85]]])

L755584 = LinearRegression(fit_intercept=True) 
L755584.fit(ca[['Week']],ffdf[[item[86]]])

L815101 = LinearRegression(fit_intercept=True) 
L815101.fit(ca[['Week']],ffdf[[item[87]]])

L836125 = LinearRegression(fit_intercept=True) 
L836125.fit(ca[['Week']],ffdf[[item[88]]])

L836152 = LinearRegression(fit_intercept=True) 
L836152.fit(ca[['Week']],ffdf[[item[89]]])

L836584 = LinearRegression(fit_intercept=True) 
L836584.fit(ca[['Week']],ffdf[[item[90]]])

L837943 = LinearRegression(fit_intercept=True) 
L837943.fit(ca[['Week']],ffdf[[item[91]]])

L838456 = LinearRegression(fit_intercept=True) 
L838456.fit(ca[['Week']],ffdf[[item[92]]])

L839356 = LinearRegression(fit_intercept=True) 
L839356.fit(ca[['Week']],ffdf[[item[93]]])

L839374 = LinearRegression(fit_intercept=True) 
L839374.fit(ca[['Week']],ffdf[[item[94]]])

L858886 = LinearRegression(fit_intercept=True) 
L858886.fit(ca[['Week']],ffdf[[item[95]]])

L865933 = LinearRegression(fit_intercept=True) 
L865933.fit(ca[['Week']],ffdf[[item[96]]])

L872260 = LinearRegression(fit_intercept=True) 
L872260.fit(ca[['Week']],ffdf[[item[97]]])

L877624 = LinearRegression(fit_intercept=True) 
L877624.fit(ca[['Week']],ffdf[[item[98]]])

L893824 = LinearRegression(fit_intercept=True) 
L893824.fit(ca[['Week']],ffdf[[item[99]]])

L903976 = LinearRegression(fit_intercept=True) 
L903976.fit(ca[['Week']],ffdf[[item[100]]])

L906586 = LinearRegression(fit_intercept=True) 
L906586.fit(ca[['Week']],ffdf[[item[101]]])

L906595 = LinearRegression(fit_intercept=True) 
L906595.fit(ca[['Week']],ffdf[[item[102]]])

L913561 = LinearRegression(fit_intercept=True) 
L913561.fit(ca[['Week']],ffdf[[item[103]]])

L999403 = LinearRegression(fit_intercept=True) 
L999403.fit(ca[['Week']],ffdf[[item[104]]])

L1003147 = LinearRegression(fit_intercept=True) 
L1003147.fit(ca[['Week']],ffdf[[item[105]]])

L1003156 = LinearRegression(fit_intercept=True) 
L1003156.fit(ca[['Week']],ffdf[[item[106]]])

L1003183 = LinearRegression(fit_intercept=True) 
L1003183.fit(ca[['Week']],ffdf[[item[107]]])

L1003192 = LinearRegression(fit_intercept=True) 
L1003192.fit(ca[['Week']],ffdf[[item[108]]])

L1006009 = LinearRegression(fit_intercept=True) 
L1006009.fit(ca[['Week']],ffdf[[item[109]]])

L1006090 = LinearRegression(fit_intercept=True) 
L1006090.fit(ca[['Week']],ffdf[[item[110]]])

L1006099 = LinearRegression(fit_intercept=True) 
L1006099.fit(ca[['Week']],ffdf[[item[111]]])

L1006108 = LinearRegression(fit_intercept=True) 
L1006108.fit(ca[['Week']],ffdf[[item[112]]])

L1010068 = LinearRegression(fit_intercept=True) 
L1010068.fit(ca[['Week']],ffdf[[item[113]]])

L1013335 = LinearRegression(fit_intercept=True) 
L1013335.fit(ca[['Week']],ffdf[[item[114]]])

L1015621 = LinearRegression(fit_intercept=True) 
L1015621.fit(ca[['Week']],ffdf[[item[115]]])

L1021264 = LinearRegression(fit_intercept=True) 
L1021264.fit(ca[['Week']],ffdf[[item[116]]])

L1024810 = LinearRegression(fit_intercept=True) 
L1024810.fit(ca[['Week']],ffdf[[item[117]]])

L1026871 = LinearRegression(fit_intercept=True) 
L1026871.fit(ca[['Week']],ffdf[[item[118]]])

L1030948 = LinearRegression(fit_intercept=True) 
L1030948.fit(ca[['Week']],ffdf[[item[119]]])

L1032532 = LinearRegression(fit_intercept=True) 
L1032532.fit(ca[['Week']],ffdf[[item[120]]])

L1032541 = LinearRegression(fit_intercept=True) 
L1032541.fit(ca[['Week']],ffdf[[item[121]]])

L1032550 = LinearRegression(fit_intercept=True) 
L1032550.fit(ca[['Week']],ffdf[[item[122]]])

L1032559 = LinearRegression(fit_intercept=True) 
L1032559.fit(ca[['Week']],ffdf[[item[123]]])

L1032568 = LinearRegression(fit_intercept=True) 
L1032568.fit(ca[['Week']],ffdf[[item[124]]])

L1032586 = LinearRegression(fit_intercept=True) 
L1032586.fit(ca[['Week']],ffdf[[item[125]]])

L1044502 = LinearRegression(fit_intercept=True) 
L1044502.fit(ca[['Week']],ffdf[[item[126]]])

L1044610 = LinearRegression(fit_intercept=True) 
L1044610.fit(ca[['Week']],ffdf[[item[127]]])

L1044619 = LinearRegression(fit_intercept=True) 
L1044619.fit(ca[['Week']],ffdf[[item[128]]])

L1044682 = LinearRegression(fit_intercept=True) 
L1044682.fit(ca[['Week']],ffdf[[item[129]]])

L1044691 = LinearRegression(fit_intercept=True) 
L1044691.fit(ca[['Week']],ffdf[[item[130]]])

L1047130 = LinearRegression(fit_intercept=True) 
L1047130.fit(ca[['Week']],ffdf[[item[131]]])

L1047967 = LinearRegression(fit_intercept=True) 
L1047967.fit(ca[['Week']],ffdf[[item[132]]])

L1048975 = LinearRegression(fit_intercept=True) 
L1048975.fit(ca[['Week']],ffdf[[item[133]]])

L1049776 = LinearRegression(fit_intercept=True) 
L1049776.fit(ca[['Week']],ffdf[[item[134]]])

L1050046 = LinearRegression(fit_intercept=True) 
L1050046.fit(ca[['Week']],ffdf[[item[135]]])

L1054978 = LinearRegression(fit_intercept=True) 
L1054978.fit(ca[['Week']],ffdf[[item[136]]])

L1056463 = LinearRegression(fit_intercept=True) 
L1056463.fit(ca[['Week']],ffdf[[item[137]]])

L1058713 = LinearRegression(fit_intercept=True) 
L1058713.fit(ca[['Week']],ffdf[[item[138]]])

L1060630 = LinearRegression(fit_intercept=True) 
L1060630.fit(ca[['Week']],ffdf[[item[139]]])

L1060909 = LinearRegression(fit_intercept=True) 
L1060909.fit(ca[['Week']],ffdf[[item[140]]])

L1061341 = LinearRegression(fit_intercept=True) 
L1061341.fit(ca[['Week']],ffdf[[item[141]]])

L1061638 = LinearRegression(fit_intercept=True) 
L1061638.fit(ca[['Week']],ffdf[[item[142]]])

L1063600 = LinearRegression(fit_intercept=True) 
L1063600.fit(ca[['Week']],ffdf[[item[143]]])

L1064473 = LinearRegression(fit_intercept=True) 
L1064473.fit(ca[['Week']],ffdf[[item[144]]])

L1064572 = LinearRegression(fit_intercept=True) 
L1064572.fit(ca[['Week']],ffdf[[item[145]]])

L1066570 = LinearRegression(fit_intercept=True) 
L1066570.fit(ca[['Week']],ffdf[[item[146]]])

L1067074 = LinearRegression(fit_intercept=True) 
L1067074.fit(ca[['Week']],ffdf[[item[147]]])

L1067092 = LinearRegression(fit_intercept=True) 
L1067092.fit(ca[['Week']],ffdf[[item[148]]])

L1067119 = LinearRegression(fit_intercept=True) 
L1067119.fit(ca[['Week']],ffdf[[item[149]]])

L1067128 = LinearRegression(fit_intercept=True) 
L1067128.fit(ca[['Week']],ffdf[[item[150]]])

L1068883 = LinearRegression(fit_intercept=True) 
L1068883.fit(ca[['Week']],ffdf[[item[151]]])

L1070818 = LinearRegression(fit_intercept=True) 
L1070818.fit(ca[['Week']],ffdf[[item[152]]])

L1070836 = LinearRegression(fit_intercept=True) 
L1070836.fit(ca[['Week']],ffdf[[item[153]]])

L1071106 = LinearRegression(fit_intercept=True) 
L1071106.fit(ca[['Week']],ffdf[[item[154]]])

L1071115 = LinearRegression(fit_intercept=True) 
L1071115.fit(ca[['Week']],ffdf[[item[155]]])

L1071124 = LinearRegression(fit_intercept=True) 
L1071124.fit(ca[['Week']],ffdf[[item[156]]])

L1074823 = LinearRegression(fit_intercept=True) 
L1074823.fit(ca[['Week']],ffdf[[item[157]]])

L1075651 = LinearRegression(fit_intercept=True) 
L1075651.fit(ca[['Week']],ffdf[[item[158]]])

L1076920 = LinearRegression(fit_intercept=True) 
L1076920.fit(ca[['Week']],ffdf[[item[159]]])

L1076929 = LinearRegression(fit_intercept=True) 
L1076929.fit(ca[['Week']],ffdf[[item[160]]])

L1076938 = LinearRegression(fit_intercept=True) 
L1076938.fit(ca[['Week']],ffdf[[item[161]]])

L1077118 = LinearRegression(fit_intercept=True) 
L1077118.fit(ca[['Week']],ffdf[[item[162]]])

L1081060 = LinearRegression(fit_intercept=True) 
L1081060.fit(ca[['Week']],ffdf[[item[163]]])

L1081069 = LinearRegression(fit_intercept=True) 
L1081069.fit(ca[['Week']],ffdf[[item[164]]])

L1081078 = LinearRegression(fit_intercept=True) 
L1081078.fit(ca[['Week']],ffdf[[item[165]]])

L1081087 = LinearRegression(fit_intercept=True) 
L1081087.fit(ca[['Week']],ffdf[[item[166]]])

L1081321 = LinearRegression(fit_intercept=True) 
L1081321.fit(ca[['Week']],ffdf[[item[167]]])

L1081339 = LinearRegression(fit_intercept=True) 
L1081339.fit(ca[['Week']],ffdf[[item[168]]])

L1082743 = LinearRegression(fit_intercept=True) 
L1082743.fit(ca[['Week']],ffdf[[item[169]]])

L1084498 = LinearRegression(fit_intercept=True) 
L1084498.fit(ca[['Week']],ffdf[[item[170]]])

L1085749 = LinearRegression(fit_intercept=True) 
L1085749.fit(ca[['Week']],ffdf[[item[171]]])

L1090024 = LinearRegression(fit_intercept=True) 
L1090024.fit(ca[['Week']],ffdf[[item[172]]])

L1090105 = LinearRegression(fit_intercept=True) 
L1090105.fit(ca[['Week']],ffdf[[item[173]]])

L1090114 = LinearRegression(fit_intercept=True) 
L1090114.fit(ca[['Week']],ffdf[[item[174]]])

L1090240 = LinearRegression(fit_intercept=True) 
L1090240.fit(ca[['Week']],ffdf[[item[175]]])

L1090249 = LinearRegression(fit_intercept=True) 
L1090249.fit(ca[['Week']],ffdf[[item[176]]])

L1090258 = LinearRegression(fit_intercept=True) 
L1090258.fit(ca[['Week']],ffdf[[item[177]]])

L1090276 = LinearRegression(fit_intercept=True) 
L1090276.fit(ca[['Week']],ffdf[[item[178]]])

L1090294 = LinearRegression(fit_intercept=True) 
L1090294.fit(ca[['Week']],ffdf[[item[179]]])

L1090303 = LinearRegression(fit_intercept=True) 
L1090303.fit(ca[['Week']],ffdf[[item[180]]])

L1092184 = LinearRegression(fit_intercept=True) 
L1092184.fit(ca[['Week']],ffdf[[item[181]]])

L1097143 = LinearRegression(fit_intercept=True) 
L1097143.fit(ca[['Week']],ffdf[[item[182]]])

L1098493 = LinearRegression(fit_intercept=True) 
L1098493.fit(ca[['Week']],ffdf[[item[183]]])

L1098502 = LinearRegression(fit_intercept=True) 
L1098502.fit(ca[['Week']],ffdf[[item[184]]])

L1101553 = LinearRegression(fit_intercept=True) 
L1101553.fit(ca[['Week']],ffdf[[item[185]]])

L1101562 = LinearRegression(fit_intercept=True) 
L1101562.fit(ca[['Week']],ffdf[[item[186]]])

L1101571 = LinearRegression(fit_intercept=True) 
L1101571.fit(ca[['Week']],ffdf[[item[187]]])

L1101661 = LinearRegression(fit_intercept=True) 
L1101661.fit(ca[['Week']],ffdf[[item[188]]])

L1101769 = LinearRegression(fit_intercept=True) 
L1101769.fit(ca[['Week']],ffdf[[item[189]]])

L1103056 = LinearRegression(fit_intercept=True) 
L1103056.fit(ca[['Week']],ffdf[[item[190]]])

L1105009 = LinearRegression(fit_intercept=True) 
L1105009.fit(ca[['Week']],ffdf[[item[191]]])

L1105018 = LinearRegression(fit_intercept=True) 
L1105018.fit(ca[['Week']],ffdf[[item[192]]])

L1105027 = LinearRegression(fit_intercept=True) 
L1105027.fit(ca[['Week']],ffdf[[item[193]]])
# Out:
# LinearRegression()

# %% [markdown]
# # **__**

# %%
locals()['L' + str(item[190])].predict([[20]])
# Out:
# array([[322.40350877]])

# %% [markdown]
# item 3418

# %%
theta_0 = L123307.intercept_

theta_1 = L123307.coef_
print(f"{theta_0}  {theta_1}")
# Out:
# [-157.71929825]  [[485.40350877]]

# %%
plt.figure(figsize=(12,6))
plt.scatter(ffdf['Week'], ffdf[123307])
plt.plot(ffdf['Week'],  float(theta_1)*ffdf['Week'] + float(theta_0), 'r')
plt.show()

# %% [markdown]
# # Validation data sorting

# %%
vd
# Out:
#     CategoryCode  ItemCode Week  WeeklySales
# 0     category_2   1044502   w1           11
# 1     category_2   1105009   w1           11
# 2     category_2    913561   w4            5
# 3     category_1   1048975   w4           30
# 4     category_1     17287   w2           60
# ..           ...       ...  ...          ...
# 365   category_2    124954   w2           43
# 366   category_2     40759   w1           48
# 367   category_1   1090303   w1           19
# 368   category_2   1090276   w3            6
# 369   category_1      3418   w4           69
#
# [370 rows x 4 columns]

# %%
vd.Week.replace("w1",20,inplace=True)
vd.Week.replace("w2",21,inplace=True)
vd.Week.replace("w3",22,inplace=True)
vd.Week.replace("w4",23,inplace=True)

# %%
vd
# Out:
#     CategoryCode  ItemCode  Week  WeeklySales
# 0     category_2   1044502    20           11
# 1     category_2   1105009    20           11
# 2     category_2    913561    23            5
# 3     category_1   1048975    23           30
# 4     category_1     17287    21           60
# ..           ...       ...   ...          ...
# 365   category_2    124954    21           43
# 366   category_2     40759    20           48
# 367   category_1   1090303    20           19
# 368   category_2   1090276    22            6
# 369   category_1      3418    23           69
#
# [370 rows x 4 columns]

# %%
fvd = vd.pivot_table(index='Week', values='WeeklySales', columns ='ItemCode', aggfunc=sum).reset_index()
fvd
# Out:
# ItemCode  Week   3418  3427  7666  17287  17296  20824  23569  24136  30877  \
# 0           20   25.0   7.0  48.0   57.0  366.0  137.0   20.0   20.0   65.0
# 1           21   69.0  56.0  16.0   60.0  514.0  150.0   60.0   56.0   93.0
# 2           22  120.0  72.0   NaN   83.0  728.0  148.0    2.0   37.0  107.0
# 3           23   69.0  33.0  17.0   64.0  771.0  220.0   20.0   44.0  118.0
#
# ItemCode  ...  1090114  1090240  1090276  1090294  1090303  1097143  1098493  \
# 0         ...      3.0      3.0      3.0     11.0     19.0     43.0     10.0
# 1         ...     11.0      8.0      4.0     32.0     11.0     47.0      8.0
# 2         ...     11.0     13.0      6.0     12.0     14.0     32.0      9.0
# 3         ...     11.0      8.0     10.0     29.0     14.0     27.0      9.0
#
# ItemCode  1098502  1101661  1105009
# 0             7.0     64.0     11.0
# 1             6.0     69.0     10.0
# 2             7.0     54.0     10.0
# 3             4.0     88.0     19.0
#
# [4 rows x 96 columns]

# %% [markdown]
# ????

# %%
fvd = vd.pivot_table(index='Week', values='WeeklySales', columns ='ItemCode', fill_value=0 ,aggfunc=sum).reset_index()
fvd
# Out:
# ItemCode  Week  3418  3427  7666  17287  17296  20824  23569  24136  30877  \
# 0           20    25     7    48     57    366    137     20     20     65
# 1           21    69    56    16     60    514    150     60     56     93
# 2           22   120    72     0     83    728    148      2     37    107
# 3           23    69    33    17     64    771    220     20     44    118
#
# ItemCode  ...  1090114  1090240  1090276  1090294  1090303  1097143  1098493  \
# 0         ...        3        3        3       11       19       43       10
# 1         ...       11        8        4       32       11       47        8
# 2         ...       11       13        6       12       14       32        9
# 3         ...       11        8       10       29       14       27        9
#
# ItemCode  1098502  1101661  1105009
# 0               7       64       11
# 1               6       69       10
# 2               7       54       10
# 3               4       88       19
#
# [4 rows x 96 columns]

# %%
# ffvd = pd.concat([fvd['Week'],fvd[item].cumsum()], axis=1)
# ffvd

# %%
td
# Out:
#     CategoryCode  ItemCode Week  PredictedSales
# 0     category_1     43738   w4             NaN
# 1     category_2   1006090   w1             NaN
# 2     category_2   1076929   w4             NaN
# 3     category_1   1081321   w3             NaN
# 4     category_2    216151   w4             NaN
# ..           ...       ...  ...             ...
# 372   category_2   1101571   w1             NaN
# 373   category_2   1090258   w4             NaN
# 374   category_2    906595   w1             NaN
# 375   category_2     32245   w1             NaN
# 376   category_2   1006090   w2             NaN
#
# [377 rows x 4 columns]

# %%
# td.Week.replace("w1",20,inplace=True)
# td.Week.replace("w2",21,inplace=True)
# td.Week.replace("w3",22,inplace=True)
# td.Week.replace("w4",23,inplace=True)

# %%
td
# Out:
#     CategoryCode  ItemCode Week  PredictedSales
# 0     category_1     43738   w4             NaN
# 1     category_2   1006090   w1             NaN
# 2     category_2   1076929   w4             NaN
# 3     category_1   1081321   w3             NaN
# 4     category_2    216151   w4             NaN
# ..           ...       ...  ...             ...
# 372   category_2   1101571   w1             NaN
# 373   category_2   1090258   w4             NaN
# 374   category_2    906595   w1             NaN
# 375   category_2     32245   w1             NaN
# 376   category_2   1006090   w2             NaN
#
# [377 rows x 4 columns]

# %%
def weekNum(x):
  if x == 'w1':
    return 20
  elif x == 'w2':
    return 21
  elif x == 'w3':
    return 22
  else:
    return 23

# %%
td['WeekNum'] = td['Week'].apply(lambda x: weekNum(x))

# %%
td
# Out:
#     CategoryCode  ItemCode Week  PredictedSales  WeekNum
# 0     category_1     43738   w4             NaN       23
# 1     category_2   1006090   w1             NaN       20
# 2     category_2   1076929   w4             NaN       23
# 3     category_1   1081321   w3             NaN       22
# 4     category_2    216151   w4             NaN       23
# ..           ...       ...  ...             ...      ...
# 372   category_2   1101571   w1             NaN       20
# 373   category_2   1090258   w4             NaN       23
# 374   category_2    906595   w1             NaN       20
# 375   category_2     32245   w1             NaN       20
# 376   category_2   1006090   w2             NaN       21
#
# [377 rows x 5 columns]

# %%
td.index
# Out:
# RangeIndex(start=0, stop=377, step=1)

# %%
td['ItemCode'].unique()
# Out:
# array([  43738, 1006090, 1076929, 1081321,  216151, 1063600, 1082743,
#          23200, 1068883,  838456, 1090258, 1032559,  123307,  837943,
#        1067119, 1056463, 1101571, 1101769,  687616, 1071115, 1081339,
#          87559, 1090024, 1044691,   65788, 1081069, 1044610,   42424,
#         858886,  119554,  267478, 1075651,  169504, 1060630,   39436,
#          57058,   87046,  906595,  753613,    9925,  815101,   37510,
#         111436,   88450, 1070818,   32245,   37861, 1103056,  903976,
#        1047967, 1105027,  893824,   86992,  999403,  111382, 1024810,
#         370195,  371104,   36898, 1054978, 1081060,  174436,  262384,
#        1032532,  872260, 1092184,  731104, 1085749,   42496,   41830,
#         145978, 1021264,  839374, 1003192,   35530,  117610, 1077118,
#        1049776,  132334, 1067074, 1101553,  225259, 1006099, 1081078,
#         145330, 1105018,   43630, 1061341,  213802, 1101562, 1003183,
#          38518, 1032568,   16936,  130993, 1067128,   35449], dtype=int64)

# %%
td.iloc[0][0]
# Out:
# 'category_1'

# %%
td['PredictedSales']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 372   NaN
# 373   NaN
# 374   NaN
# 375   NaN
# 376   NaN
# Name: PredictedSales, Length: 377, dtype: float64

# %%
int(td.iloc[0][4])
# Out:
# 23

# %% [markdown]
# # Predicting Sales

# %%
for x in range(377):
  ss = locals()['L' + str(int(td.iloc[x][1]))].predict([[int(td.iloc[x][4])]])
  sss = locals()['L' + str(int(td.iloc[x][1]))].predict([[int(td.iloc[x][4])-1]])
  td.iat[x,3] = float(ss - sss)

# %%
int(4.6)
# Out:
# 4

# %%
td
# Out:
#     CategoryCode  ItemCode Week  PredictedSales  WeekNum
# 0     category_1     43738   w4       18.449123       23
# 1     category_2   1006090   w1       20.226316       20
# 2     category_2   1076929   w4       13.070175       23
# 3     category_1   1081321   w3       15.829825       22
# 4     category_2    216151   w4       17.243860       23
# ..           ...       ...  ...             ...      ...
# 372   category_2   1101571   w1       22.754386       20
# 373   category_2   1090258   w4       25.466667       23
# 374   category_2    906595   w1        9.691228       20
# 375   category_2     32245   w1       39.512281       20
# 376   category_2   1006090   w2       20.226316       21
#
# [377 rows x 5 columns]

# %%
def proper_round(num, dec=0):
    num = str(num)[:str(num).index('.')+dec+2]
    if num[-1]>='5':
        return float(num[:-2-(not dec)]+str(int(num[-2-(not dec)])+1))
    return float(num[:-1])

# %%
proper_round(2.5)
# Out:
# 3.0

# %%
td['fPredictedSales'] = td.PredictedSales.apply(lambda x: proper_round(x))
td
# Out:
#     CategoryCode  ItemCode Week  PredictedSales  WeekNum  fPredictedSales
# 0     category_1     43738   w4       18.449123       23             18.0
# 1     category_2   1006090   w1       20.226316       20             20.0
# 2     category_2   1076929   w4       13.070175       23             13.0
# 3     category_1   1081321   w3       15.829825       22             16.0
# 4     category_2    216151   w4       17.243860       23             17.0
# ..           ...       ...  ...             ...      ...              ...
# 372   category_2   1101571   w1       22.754386       20             23.0
# 373   category_2   1090258   w4       25.466667       23             25.0
# 374   category_2    906595   w1        9.691228       20             10.0
# 375   category_2     32245   w1       39.512281       20            310.0
# 376   category_2   1006090   w2       20.226316       21             20.0
#
# [377 rows x 6 columns]

# %%
td['fPredictedSales'] = td['fPredictedSales'].astype(str).apply(lambda x: x.replace('.0',''))

# %%
td
# Out:
#     CategoryCode  ItemCode Week  PredictedSales  WeekNum fPredictedSales
# 0     category_1     43738   w4       18.449123       23              18
# 1     category_2   1006090   w1       20.226316       20              20
# 2     category_2   1076929   w4       13.070175       23              13
# 3     category_1   1081321   w3       15.829825       22              16
# 4     category_2    216151   w4       17.243860       23              17
# ..           ...       ...  ...             ...      ...             ...
# 372   category_2   1101571   w1       22.754386       20              23
# 373   category_2   1090258   w4       25.466667       23              25
# 374   category_2    906595   w1        9.691228       20              10
# 375   category_2     32245   w1       39.512281       20             310
# 376   category_2   1006090   w2       20.226316       21              20
#
# [377 rows x 6 columns]

# %% [markdown]
# # validation data

# %%
fvd
# Out:
# ItemCode  Week  3418  3427  7666  17287  17296  20824  23569  24136  30877  \
# 0           20    25     7    48     57    366    137     20     20     65
# 1           21    69    56    16     60    514    150     60     56     93
# 2           22   120    72     0     83    728    148      2     37    107
# 3           23    69    33    17     64    771    220     20     44    118
#
# ItemCode  ...  1090114  1090240  1090276  1090294  1090303  1097143  1098493  \
# 0         ...        3        3        3       11       19       43       10
# 1         ...       11        8        4       32       11       47        8
# 2         ...       11       13        6       12       14       32        9
# 3         ...       11        8       10       29       14       27        9
#
# ItemCode  1098502  1101661  1105009
# 0               7       64       11
# 1               6       69       10
# 2               7       54       10
# 3               4       88       19
#
# [4 rows x 96 columns]

# %%
vd
# Out:
#     CategoryCode  ItemCode  Week  WeeklySales
# 0     category_2   1044502    20           11
# 1     category_2   1105009    20           11
# 2     category_2    913561    23            5
# 3     category_1   1048975    23           30
# 4     category_1     17287    21           60
# ..           ...       ...   ...          ...
# 365   category_2    124954    21           43
# 366   category_2     40759    20           48
# 367   category_1   1090303    20           19
# 368   category_2   1090276    22            6
# 369   category_1      3418    23           69
#
# [370 rows x 4 columns]

# %% [markdown]
# # Total Mean Absolute Percentage Error

# %%
TMAPE = 0.0000
www = []
nww = []
sww = [] #
pww = []

for i in range(370):
  www.append(vd.iloc[i][1])
  nww.append(vd.iloc[i][2])
  sww.append(vd.iloc[i][3])

for i in range(370):
  pww.append(float(locals()['L' + str(int(vd.iloc[i][1]))].predict([[int(vd.iloc[i][2])]])))


for i in range(len(pww)):
  pww[i] = int(proper_round(pww[i]))

upsum = 0.000
for i in range(370):
  upsum = upsum + abs(pww[i] - sww[i])

dsum = 0.000
for i in range(370):
  dsum = dsum + sww[i]

TMAPE = upsum/dsum
TMAPE
# Out:
# 30.10738891346944

# %%
print(f"Total Mean Absolute Percentage Error:- {TMAPE}")
# Out:
# Total Mean Absolute Percentage Error:- 30.10738891346944

# %% [markdown]
# # Submission

# %%
submission_file = pd.DataFrame()

# %%
submission_file['ID'] = td['CategoryCode'].astype(str)+'_'+td['ItemCode'].astype(str)+'_'+td['Week']
submission_file['WeeklySales'] = td['fPredictedSales']

# %%
submission_file
# Out:
#                         ID WeeklySales
# 0      category_1_43738_w4          18
# 1    category_2_1006090_w1          20
# 2    category_2_1076929_w4          13
# 3    category_1_1081321_w3          16
# 4     category_2_216151_w4          17
# ..                     ...         ...
# 372  category_2_1101571_w1          23
# 373  category_2_1090258_w4          25
# 374   category_2_906595_w1          10
# 375    category_2_32245_w1         310
# 376  category_2_1006090_w2          20
#
# [377 rows x 2 columns]

# %%
submission_file.to_csv('submission.csv', index=False)
